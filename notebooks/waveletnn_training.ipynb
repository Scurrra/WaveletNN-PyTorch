# %% [markdown]
# <a href="https://colab.research.google.com/github/Scurrra/WaveletNN-PyTorch/blob/master/notebooks/waveletnn_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WaveletNN Training
#
# Example of training 1D orthonormal and biorthogonal wavelets with [PyWavelets](https://pywavelets.readthedocs.io/) generated analysis, i.e. learning an existing wavelet.

# %% [markdown]
# ## Install `waveletnn` and `pywt` packages.

# %%
# !pip install -qq waveletnn
# !pip install -qq PyWavelets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 30.9 MB/s eta 0:00:00

# %%
import torch
import numpy as np

from waveletnn import *
import pywt

# %% [markdown]
# ## Adopt `pywt` analysis to match those of `waveletnn`

# %%
def analyze(signal, wavelet, padding: int, mode:str="antireflect", levels:int=1):
    assert mode in pywt.Modes.modes
    signals, details = [], []

    for _ in range(levels):
        signal = pywt.pad(signal, (padding,), mode)
        signal, detail = pywt.dwt(signal, wavelet, mode="zero")

        signals.append(torch.from_numpy(signal[(padding):(-padding)]))
        details.append(torch.from_numpy(detail[(padding):(-padding)]))

        signal = signal[(padding):(-padding)]

    return signals, details

# %%
def synthesize(packet, wavelet, padding: int, levels:int=1):
    signal, details = packet
    z = pywt.idwt(
        pywt.pad(signal[-1], (padding,padding), "zero"),
        pywt.pad(details[-1], (padding,padding), "zero"),
        wavelet, mode="zero"
    )
    for i in range(levels-2, -1, -1):
        z = pywt.idwt(
            pywt.pad(z[padding:(-padding)], (padding,padding), "zero"),
            pywt.pad(details[i], (padding,padding), "zero"),
            wavelet, mode="zero"
        )
    return z[padding:(-padding)]

# %%
mode = "antireflect"
wavelet = "db8"
# "db8" is of length 16 so the padding is 7, this will be shown later
padding = 7

# %%
x = np.random.rand(512)

# %%
signal, details = analyze(x, wavelet, padding, levels=3, mode=mode)
[len(signal[i]) for i in range(3)], [len(details[i]) for i in range(3)]
# Out:
# ([256, 128, 64], [256, 128, 64])

# %%
z = synthesize(
    analyze(x, wavelet, padding, levels=3, mode=mode),
    wavelet, padding, levels=3
)
len(z)
# Out:
# 512

# %%
# not perfect because of need to trim pywt output
sum((x-z) ** 2)
# Out:
# 15.86329858816335

# %% [markdown]
# ## Closer integration with `waeletnn` and bath support

# %%
def analyze_batch(signal, wavelet, padding: int, mode:str="antireflect", levels:int=1):
    pad = PadSequence(padding, padding, mode)

    signals, details = [], []

    for _ in range(levels):
        signal = pad(signal).numpy()
        signal, detail = pywt.dwt(signal, wavelet, mode="zero")

        signals.append(torch.from_numpy(signal[..., (padding):(-padding)]))
        details.append(torch.from_numpy(detail[..., (padding):(-padding)]))

        signal = signals[-1]

    return signals, details

# %%
def synthesize_batch(packet, wavelet, padding: int, levels:int=1):
    pad = PadSequence(padding, padding, "constant")

    signal, details = packet
    z = torch.from_numpy(pywt.idwt(
        pad(signal[-1]).numpy(),
        pad(details[-1]).numpy(),
        wavelet, mode="zero"
    ))
    for i in range(levels-2, -1, -1):
        z = torch.from_numpy(pywt.idwt(
            pad(z[..., padding:(-padding)]).numpy(),
            pad(details[i]).numpy(),
            wavelet, mode="zero"
        ))
    return z[..., padding:(-padding)]

# %%
x = torch.randn(5,1,512)
x.shape
# Out:
# torch.Size([5, 1, 512])

# %%
signal, details = analyze_batch(x, wavelet, padding, levels=3, mode=mode)
[signal[i].shape for i in range(3)], [details[i].shape for i in range(3)]
# Out:
# ([torch.Size([5, 1, 256]), torch.Size([5, 1, 128]), torch.Size([5, 1, 64])],
#  [torch.Size([5, 1, 256]), torch.Size([5, 1, 128]), torch.Size([5, 1, 64])])

# %%
z = synthesize_batch(
    analyze_batch(x, wavelet, padding, levels=3, mode=mode),
    wavelet, padding, levels=3
)
z.shape
# Out:
# torch.Size([5, 1, 512])

# %%
((x-z) ** 2).sum()
# Out:
# tensor(79.7877)

# %% [markdown]
# ## Train and Test functions

# %%
def train_loop(model, wavelet, loss_fn, loss_reg, optimizer, batch_size=8, num_of_steps=500, log_step=100):
    model.train()
    for batch in range(num_of_steps):
        # Compute prediction and loss
        X = torch.rand(batch_size, 1, 512)
        (Ys, Yd), (h, g) = model(X, return_filters=True)
        (Zs, Zd) = analyze_batch(X, wavelet, padding=model.padding, levels=model.levels)

        loss = loss_reg(h, g)
        for i in range(model.levels):
            loss += loss_fn(Ys[i], Zs[i])
            loss += loss_fn(Yd[i], Zd[i])

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % log_step == 0:
            loss = loss.item()
            print(f"loss: {loss:>7f}  [{batch:>5d}/{num_of_steps:>5d}]")


def test_loop(model, wavelet, loss_fn, loss_reg, batch_size=8, n_tests=100):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    test_loss_fn, test_loss_reg = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for _ in range(n_tests):
            X = torch.rand(batch_size, 1, 512)
            (Ys, Yd), (h, g) = model(X, return_filters=True)
            (Zs, Zd) = analyze_batch(X, wavelet, padding=model.padding, levels=model.levels)

            test_loss_reg += loss_reg(h, g).item()
            for i in range(model.levels):
                test_loss_fn += loss_fn(Ys[i], Zs[i])
                test_loss_fn += loss_fn(Yd[i], Zd[i])

    test_loss_fn /= n_tests
    test_loss_reg /= n_tests
    print(f"Test Error: Avg MSE loss: {test_loss_fn:>8f}, Wavelet loss: {test_loss_reg:>8f} \n")

# %% [markdown]
# ## Train orthonormal wavelet

# %%
wl_db9 = pywt.Wavelet("db9")
wl_db9.dec_len
# Out:
# 18

# %%
wavelet_h = wl_db9.dec_lo.copy()
wavelet_h.reverse()
wavelet_h = torch.tensor(wavelet_h, dtype=torch.get_default_dtype())
wavelet_h
# Out:
# tensor([ 3.8078e-02,  2.4383e-01,  6.0482e-01,  6.5729e-01,  1.3320e-01,
#         -2.9327e-01, -9.6841e-02,  1.4854e-01,  3.0726e-02, -6.7633e-02,
#          2.5095e-04,  2.2362e-02, -4.7232e-03, -4.2815e-03,  1.8476e-03,
#          2.3039e-04, -2.5196e-04,  3.9347e-05])

# %%
wavelet_g = wl_db9.dec_hi.copy()
wavelet_g.reverse()
wavelet_g = torch.tensor(wavelet_g, dtype=torch.get_default_dtype())
wavelet_g
# Out:
# tensor([ 3.9347e-05,  2.5196e-04,  2.3039e-04, -1.8476e-03, -4.2815e-03,
#          4.7232e-03,  2.2362e-02, -2.5095e-04, -6.7633e-02, -3.0726e-02,
#          1.4854e-01,  9.6841e-02, -2.9327e-01, -1.3320e-01,  6.5729e-01,
#         -6.0482e-01,  2.4383e-01, -3.8078e-02])

# %%
model = OrthonormalWaveletBlock1D(wl_db9.dec_len, levels=3)
print(model)
# Out:
# OrthonormalWaveletBlock1D(
#   (pad): PadSequence()
# )

# %%
loss_fn = torch.nn.MSELoss()
loss_reg = OrthonormalWaveletRegularization(n_moments=lambda _: 8) # db9 is known to have 8 vanishing moments

# %%
for p in range(1, 8+1):
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

    loss_reg_p = OrthonormalWaveletRegularization(n_moments=lambda _, max_p=p: max_p)
    for t in range(20):
        print(f"Epoch {(p-1)*20+t+1}\n-------------------------------")
        train_loop(model, wl_db9, loss_fn, loss_reg_p, optimizer, batch_size=8)
        test_loop(model, wl_db9, loss_fn, loss_reg_p)
        scheduler.step()
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 10.752133  [    0/  500]
# loss: 2.902512  [  100/  500]
# loss: 2.642475  [  200/  500]
# loss: 4.660428  [  300/  500]
# loss: 1.621223  [  400/  500]
# Test Error: Avg MSE loss: 1.303443, Wavelet loss: 0.119339
#
# Epoch 2
# -------------------------------
# loss: 1.223843  [    0/  500]
# loss: 1.558472  [  100/  500]
# loss: 1.339987  [  200/  500]
# loss: 0.919167  [  300/  500]
# loss: 1.171949  [  400/  500]
# Test Error: Avg MSE loss: 0.837195, Wavelet loss: 0.081192
#
# Epoch 3
# -------------------------------
# loss: 0.999043  [    0/  500]
# loss: 0.805553  [  100/  500]
# loss: 0.830221  [  200/  500]
# loss: 0.604362  [  300/  500]
# loss: 0.597777  [  400/  500]
# Test Error: Avg MSE loss: 0.502033, Wavelet loss: 0.037185
#
# Epoch 4
# -------------------------------
# loss: 0.736610  [    0/  500]
# loss: 0.461653  [  100/  500]
# loss: 0.318172  [  200/  500]
# loss: 0.525857  [  300/  500]
# loss: 0.228041  [  400/  500]
# Test Error: Avg MSE loss: 0.183256, Wavelet loss: 0.027392
#
# Epoch 5
# -------------------------------
# loss: 0.194356  [    0/  500]
# loss: 0.154688  [  100/  500]
# loss: 0.085934  [  200/  500]
# loss: 0.065204  [  300/  500]
# loss: 0.037336  [  400/  500]
# Test Error: Avg MSE loss: 0.024389, Wavelet loss: 0.000996
#
# Epoch 6
# -------------------------------
# loss: 0.034778  [    0/  500]
# loss: 0.017652  [  100/  500]
# loss: 0.013553  [  200/  500]
# loss: 0.009686  [  300/  500]
# loss: 0.008519  [  400/  500]
# Test Error: Avg MSE loss: 0.006217, Wavelet loss: 0.000094
#
# Epoch 7
# -------------------------------
# loss: 0.005656  [    0/  500]
# loss: 0.004172  [  100/  500]
# loss: 0.003254  [  200/  500]
# loss: 0.002059  [  300/  500]
# loss: 0.001303  [  400/  500]
# Test Error: Avg MSE loss: 0.001079, Wavelet loss: 0.000006
#
# Epoch 8
# -------------------------------
# loss: 0.001025  [    0/  500]
# loss: 0.000780  [  100/  500]
# loss: 0.000567  [  200/  500]
# loss: 0.000426  [  300/  500]
# loss: 0.000199  [  400/  500]
# Test Error: Avg MSE loss: 0.000127, Wavelet loss: 0.000000
#
# Epoch 9
# -------------------------------
# loss: 0.000110  [    0/  500]
# loss: 0.000082  [  100/  500]
# loss: 0.000037  [  200/  500]
# loss: 0.000028  [  300/  500]
# loss: 0.000013  [  400/  500]
# Test Error: Avg MSE loss: 0.000009, Wavelet loss: 0.000000
#
# Epoch 10
# -------------------------------
# loss: 0.000007  [    0/  500]
# loss: 0.000005  [  100/  500]
# loss: 0.000003  [  200/  500]
# loss: 0.000001  [  300/  500]
# loss: 0.000001  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 11
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 12
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 13
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 14
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 15
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 16
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 17
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 18
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 19
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 20
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 21
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 22
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 23
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 24
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 25
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000001  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 26
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 27
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 28
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 29
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000013  [  300/  500]
# loss: 0.000002  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 30
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000002  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 31
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 32
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 33
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 34
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 35
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 36
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 37
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 38
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 39
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 40
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 41
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 42
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000033  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 43
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000034  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000002
#
# Epoch 44
# -------------------------------
# loss: 0.000002  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 45
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000001  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 46
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 47
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 48
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 49
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000002  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 50
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000003  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 51
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 52
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 53
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 54
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 55
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 56
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 57
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 58
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 59
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 60
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000001
#
# Epoch 61
# -------------------------------
# loss: 0.000020  [    0/  500]
# loss: 0.000002  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 62
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 63
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 64
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 65
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000015  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 66
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 67
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 68
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 69
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 70
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 71
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 72
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 73
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 74
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 75
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000005, Wavelet loss: 0.000740
#
# Epoch 76
# -------------------------------
# loss: 0.000745  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 77
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 78
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 79
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 80
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 81
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000132  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 82
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 83
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 84
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 85
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.019018  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 86
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 87
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 88
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 89
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 90
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 91
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 92
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 93
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 94
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 95
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 96
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 97
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 98
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 99
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 100
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000115  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 101
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.006400  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 102
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 103
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 104
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 105
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.004473  [  100/  500]
# loss: 0.000001  [  200/  500]
# loss: 0.000009  [  300/  500]
# loss: 0.012064  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000010
#
# Epoch 106
# -------------------------------
# loss: 0.000010  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 107
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 108
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000002
#
# Epoch 109
# -------------------------------
# loss: 0.000002  [    0/  500]
# loss: 0.000061  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000001  [  300/  500]
# loss: 0.000003  [  400/  500]
# Test Error: Avg MSE loss: 0.000001, Wavelet loss: 0.172926
#
# Epoch 110
# -------------------------------
# loss: 0.172927  [    0/  500]
# loss: 0.000002  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000268  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000001
#
# Epoch 111
# -------------------------------
# loss: 0.000001  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 112
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 113
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000001
#
# Epoch 114
# -------------------------------
# loss: 0.000001  [    0/  500]
# loss: 0.033175  [  100/  500]
# loss: 0.000001  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 115
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.034739  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000007
#
# Epoch 116
# -------------------------------
# loss: 0.000007  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 117
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 118
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000001  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.007187
#
# Epoch 119
# -------------------------------
# loss: 0.007187  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000149  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000007
#
# Epoch 120
# -------------------------------
# loss: 0.000007  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.001540  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.004105
#
# Epoch 121
# -------------------------------
# loss: 0.217998  [    0/  500]
# loss: 0.314162  [  100/  500]
# loss: 0.000007  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 122
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 123
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 124
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000012  [  300/  500]
# loss: 0.000089  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.554889
#
# Epoch 125
# -------------------------------
# loss: 0.554889  [    0/  500]
# loss: 0.027942  [  100/  500]
# loss: 0.000162  [  200/  500]
# loss: 0.312423  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000001, Wavelet loss: 26.715136
#
# Epoch 126
# -------------------------------
# loss: 26.715136  [    0/  500]
# loss: 0.000817  [  100/  500]
# loss: 0.000009  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 127
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 128
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 129
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 130
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 131
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 132
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 133
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 134
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 135
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 136
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 137
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 138
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 139
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 140
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 141
# -------------------------------
# loss: 0.000002  [    0/  500]
# loss: 18.856768  [  100/  500]
# loss: 0.000781  [  200/  500]
# loss: 0.000008  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 142
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 143
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 144
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 145
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 146
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 147
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 148
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 149
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 150
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 151
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 152
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 153
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 154
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 155
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 156
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 157
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 158
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 159
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 160
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Done!

# %%
X = torch.rand(10, 1, 512)
(Ys, Yd), (h, g) = model(X, return_filters=True)
(Zs, Zd) = analyze_batch(X, wl_db9, padding=model.padding, levels=model.levels)

# %%
loss = loss_reg(h, g)
print(loss)
for i in range(model.levels):
    loss += loss_fn(Yd[i], Zd[i])
    loss += loss_fn(Ys[i], Zs[i])
    print(loss)
# Out:
# tensor(2.1434e-09, grad_fn=<AddBackward0>)
# tensor(2.1950e-09, grad_fn=<AddBackward0>)
# tensor(2.3903e-09, grad_fn=<AddBackward0>)
# tensor(3.1452e-09, grad_fn=<AddBackward0>)

# %%
loss_fn(h.detach(), wavelet_h)
# Out:
# tensor(9.2117e-12)

# %%
h.detach() - wavelet_h
# Out:
# tensor([ 1.4156e-07, -2.2352e-07, -4.1723e-07,  6.5565e-07,  2.0862e-07,
#         -6.5565e-07, -2.2352e-07, -5.0664e-07, -4.0978e-08, -8.9407e-08,
#          7.4413e-07, -3.0175e-07, -3.8184e-08,  7.0641e-07, -6.2527e-07,
#          5.2986e-06, -2.1083e-07, -1.1606e-05])

# %%
g.detach() - wavelet_g
# Out:
# tensor([-1.1606e-05,  2.1083e-07,  5.2986e-06,  6.2527e-07,  7.0641e-07,
#          3.8184e-08, -3.0175e-07, -7.4413e-07, -8.9407e-08,  4.0978e-08,
#         -5.0664e-07,  2.2352e-07, -6.5565e-07, -2.0862e-07,  6.5565e-07,
#          4.1723e-07, -2.2352e-07, -1.4156e-07])

# %%
r = torch.arange(len(g), dtype=torch.get_default_dtype())
pNorm=lambda p: np.sqrt(2) / (2 ** p)
n_moments=lambda g: 8
[
    (torch.dot(r ** (p-1), g.detach()) * pNorm(p)) ** 2
    for p in range(1, n_moments(g))
]
# Out:
# [tensor(1.9771e-11),
#  tensor(4.8033e-12),
#  tensor(2.9104e-11),
#  tensor(1.4261e-09),
#  tensor(4.6566e-10),
#  tensor(0.),
#  tensor(0.)]

# %%
[
    (torch.dot(r ** (p-1), wavelet_g) * pNorm(p)) ** 2
    for p in range(1, n_moments(wavelet_g))
]
# Out:
# [tensor(4.4409e-16),
#  tensor(0.),
#  tensor(4.5475e-13),
#  tensor(2.6193e-10),
#  tensor(1.8626e-09),
#  tensor(2.9802e-08),
#  tensor(1.9073e-06)]

# %%
inv_model = InverseWaveletBlock1D(model.kernel_size, levels=3, scaling_kernel=h, wavelet_kernel=g)
inv_model
# Out:
# InverseWaveletBlock1D(
#   (pad): PadSequence()
# )

# %%
XX = inv_model(Ys[-1], Yd)
XX.shape
# Out:
# torch.Size([10, 1, 512])

# %%
((X - XX) ** 2).sum()
# Out:
# tensor(99.9788, grad_fn=<SumBackward0>)

# %% [markdown]
# ## Train biorthogonal wavelet

# %%
wl_bior68 = pywt.Wavelet("bior6.8")
wl_bior68.dec_len
# Out:
# 18

# %%
wavelet_h = wl_bior68.dec_lo.copy()
wavelet_h.reverse()
wavelet_h = torch.tensor(wavelet_h, dtype=torch.get_default_dtype())
wavelet_h
# Out:
# tensor([ 0.0019, -0.0019, -0.0170,  0.0119,  0.0497, -0.0773, -0.0941,  0.4208,
#          0.8259,  0.4208, -0.0941, -0.0773,  0.0497,  0.0119, -0.0170, -0.0019,
#          0.0019,  0.0000])

# %%
wavelet_g = wl_bior68.dec_hi.copy()
wavelet_g.reverse()
wavelet_g = torch.tensor(wavelet_g, dtype=torch.get_default_dtype())
wavelet_g
# Out:
# tensor([ 0.0000, -0.0000,  0.0000, -0.0000,  0.0144, -0.0145, -0.0787,  0.0404,
#          0.4178, -0.7589,  0.4178,  0.0404, -0.0787, -0.0145,  0.0144, -0.0000,
#          0.0000, -0.0000])

# %%
model = BiorthogonalWaveletBlock1D(wl_bior68.dec_len, levels=3)
print(model)
# Out:
# BiorthogonalWaveletBlock1D(
#   (pad): PadSequence()
# )

# %%
loss_fn = torch.nn.MSELoss()
loss_reg = BiorthogonalWaveletRegularization(n_moments=lambda _: model.kernel_size // 3)

# %%
for p in range(1, model.kernel_size // 3 + 1):
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)

    loss_reg_p = BiorthogonalWaveletRegularization(n_moments=lambda _, max_p=p: max_p)
    for t in range(20):
        print(f"Epoch {(p-1)*20+t+1}\n-------------------------------")
        train_loop(model, wl_bior68, loss_fn, loss_reg_p, optimizer, batch_size=8)
        test_loop(model, wl_bior68, loss_fn, loss_reg_p)
        scheduler.step()
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 23.081833  [    0/  500]
# loss: 1.026341  [  100/  500]
# loss: 0.812883  [  200/  500]
# loss: 0.662254  [  300/  500]
# loss: 0.424941  [  400/  500]
# Test Error: Avg MSE loss: 0.188710, Wavelet loss: 0.000822
#
# Epoch 2
# -------------------------------
# loss: 0.189314  [    0/  500]
# loss: 0.062022  [  100/  500]
# loss: 0.019098  [  200/  500]
# loss: 0.007316  [  300/  500]
# loss: 0.002492  [  400/  500]
# Test Error: Avg MSE loss: 0.000814, Wavelet loss: 0.000001
#
# Epoch 3
# -------------------------------
# loss: 0.000780  [    0/  500]
# loss: 0.000235  [  100/  500]
# loss: 0.000064  [  200/  500]
# loss: 0.000014  [  300/  500]
# loss: 0.000003  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 4
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 5
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 6
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 7
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 8
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 9
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000007  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 10
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000080  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000008, Wavelet loss: 0.000005
#
# Epoch 11
# -------------------------------
# loss: 0.000013  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 12
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 13
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000019  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 14
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000001  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 15
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000005  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000009, Wavelet loss: 0.000005
#
# Epoch 16
# -------------------------------
# loss: 0.000013  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 17
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 18
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 19
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000002  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 20
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000005  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000017, Wavelet loss: 0.000010
#
# Epoch 21
# -------------------------------
# loss: 0.000032  [    0/  500]
# loss: 0.000011  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 22
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 23
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 24
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 25
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000176  [  200/  500]
# loss: 0.000014  [  300/  500]
# loss: 0.000302  [  400/  500]
# Test Error: Avg MSE loss: 0.000002, Wavelet loss: 0.000000
#
# Epoch 26
# -------------------------------
# loss: 0.000002  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 27
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 28
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000870, Wavelet loss: 0.000079
#
# Epoch 29
# -------------------------------
# loss: 0.000948  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000050  [  200/  500]
# loss: 0.000006  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000015, Wavelet loss: 0.000012
#
# Epoch 30
# -------------------------------
# loss: 0.000027  [    0/  500]
# loss: 0.000012  [  100/  500]
# loss: 0.000001  [  200/  500]
# loss: 0.000120  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000015, Wavelet loss: 0.000001
#
# Epoch 31
# -------------------------------
# loss: 0.000017  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 32
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 33
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000003, Wavelet loss: 0.000003
#
# Epoch 34
# -------------------------------
# loss: 0.000006  [    0/  500]
# loss: 0.000028  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000015  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 35
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000064  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000102  [  300/  500]
# loss: 0.000023  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 36
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 37
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 38
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000020, Wavelet loss: 0.000006
#
# Epoch 39
# -------------------------------
# loss: 0.000027  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000004  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000003, Wavelet loss: 0.000000
#
# Epoch 40
# -------------------------------
# loss: 0.000003  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000009  [  200/  500]
# loss: 0.000003  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 41
# -------------------------------
# loss: 0.000001  [    0/  500]
# loss: 0.000085  [  100/  500]
# loss: 0.000004  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 42
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 43
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000003, Wavelet loss: 0.000359
#
# Epoch 44
# -------------------------------
# loss: 0.000362  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000029  [  400/  500]
# Test Error: Avg MSE loss: 0.001295, Wavelet loss: 0.007404
#
# Epoch 45
# -------------------------------
# loss: 0.008714  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000003  [  200/  500]
# loss: 0.000008  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000007, Wavelet loss: 0.000044
#
# Epoch 46
# -------------------------------
# loss: 0.000051  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 47
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 48
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000001
#
# Epoch 49
# -------------------------------
# loss: 0.000001  [    0/  500]
# loss: 0.000006  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000077  [  300/  500]
# loss: 0.000005  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 50
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000073  [  100/  500]
# loss: 0.000001  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000006
#
# Epoch 51
# -------------------------------
# loss: 0.000006  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 52
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 53
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 54
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000005  [  100/  500]
# loss: 0.000002  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000176  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 55
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000512  [  100/  500]
# loss: 0.000012  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000001  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000001
#
# Epoch 56
# -------------------------------
# loss: 0.000001  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 57
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 58
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 59
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000014  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000001
#
# Epoch 60
# -------------------------------
# loss: 0.000001  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000002  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000042  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 61
# -------------------------------
# loss: 0.000001  [    0/  500]
# loss: 0.000616  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 62
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 63
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 64
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000005
#
# Epoch 65
# -------------------------------
# loss: 0.000005  [    0/  500]
# loss: 0.000352  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.464413  [  300/  500]
# loss: 0.001837  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 66
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 67
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 68
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000001, Wavelet loss: 0.000084
#
# Epoch 69
# -------------------------------
# loss: 0.000085  [    0/  500]
# loss: 0.000007  [  100/  500]
# loss: 0.000001  [  200/  500]
# loss: 0.000003  [  300/  500]
# loss: 0.000019  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000005
#
# Epoch 70
# -------------------------------
# loss: 0.000005  [    0/  500]
# loss: 0.000872  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.002506  [  300/  500]
# loss: 0.000008  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 71
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 72
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 73
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000019
#
# Epoch 74
# -------------------------------
# loss: 0.000019  [    0/  500]
# loss: 0.000001  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.010776  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000001
#
# Epoch 75
# -------------------------------
# loss: 0.000001  [    0/  500]
# loss: 0.012350  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000003  [  300/  500]
# loss: 0.000015  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 76
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 77
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 78
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000004, Wavelet loss: 0.001014
#
# Epoch 79
# -------------------------------
# loss: 0.001018  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000097  [  200/  500]
# loss: 0.000008  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 80
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000008  [  100/  500]
# loss: 0.000005  [  200/  500]
# loss: 0.001098  [  300/  500]
# loss: 0.000140  [  400/  500]
# Test Error: Avg MSE loss: 0.000002, Wavelet loss: 0.000281
#
# Epoch 81
# -------------------------------
# loss: 0.011980  [    0/  500]
# loss: 0.025062  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 82
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 83
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 84
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000001, Wavelet loss: 0.004098
#
# Epoch 85
# -------------------------------
# loss: 0.004098  [    0/  500]
# loss: 0.000336  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.006619  [  300/  500]
# loss: 0.000252  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 86
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 87
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 88
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 89
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 117.002136  [  100/  500]
# loss: 0.002355  [  200/  500]
# loss: 0.000002  [  300/  500]
# loss: 0.000690  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 90
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.001323  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.001962
#
# Epoch 91
# -------------------------------
# loss: 0.001962  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 92
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 93
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 94
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 95
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.316834  [  100/  500]
# loss: 0.000001  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 96
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 97
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 98
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 99
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 100
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.001537  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 101
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 1.279058  [  100/  500]
# loss: 0.000018  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 102
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 103
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 104
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.004157
#
# Epoch 105
# -------------------------------
# loss: 0.004157  [    0/  500]
# loss: 0.099791  [  100/  500]
# loss: 0.000011  [  200/  500]
# loss: 117.449608  [  300/  500]
# loss: 0.000114  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000005
#
# Epoch 106
# -------------------------------
# loss: 0.000005  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 107
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 108
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 109
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 110
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 111
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 112
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 113
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 114
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 115
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 116
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 117
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 118
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 119
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 0.000000  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000000
#
# Epoch 120
# -------------------------------
# loss: 0.000000  [    0/  500]
# loss: 0.000000  [  100/  500]
# loss: 0.000000  [  200/  500]
# loss: 0.000000  [  300/  500]
# loss: 3.150158  [  400/  500]
# Test Error: Avg MSE loss: 0.000000, Wavelet loss: 0.000010
#
# Done!

# %%
X = torch.rand(10, 1, 512)
(Ys, Yd), (h, g) = model(X, return_filters=True)
(Zs, Zd) = analyze_batch(X, wl_bior68, padding=model.padding, levels=model.levels)

# %%
loss = loss_reg(h, g)
print(loss)
for i in range(model.levels):
    loss += loss_fn(Yd[i], Zd[i])
    loss += loss_fn(Ys[i], Zs[i])
    print(loss)
# Out:
# tensor(1.0492e-05, grad_fn=<AddBackward0>)
# tensor(1.0492e-05, grad_fn=<AddBackward0>)
# tensor(1.0492e-05, grad_fn=<AddBackward0>)
# tensor(1.0492e-05, grad_fn=<AddBackward0>)

# %%
loss_fn(h[0].detach(), wavelet_h)
# Out:
# tensor(2.3983e-13)

# %%
h[0].detach() - wavelet_h
# Out:
# tensor([ 2.4040e-07, -1.5658e-07,  3.9116e-07, -1.0990e-07, -6.7055e-08,
#         -3.5763e-07,  2.5332e-07,  5.9605e-08,  4.7684e-07,  1.4901e-07,
#          4.3213e-07, -9.3132e-07, -3.5018e-07, -2.8964e-07,  2.7940e-07,
#         -1.1884e-06,  3.5902e-07,  8.6026e-07])

# %%
g[0].detach() - wavelet_g
# Out:
# tensor([-1.9170e-06, -1.4400e-07,  2.2368e-06,  2.4637e-07,  8.0094e-08,
#          3.6228e-07,  3.2783e-07, -1.1176e-07, -5.0664e-07,  2.3842e-07,
#         -2.3842e-07,  9.6858e-08,  1.4901e-07,  1.6671e-07, -4.2841e-08,
#          8.2682e-08,  4.4308e-08,  1.3144e-07])

# %%
r = torch.arange(len(g[0]), dtype=torch.get_default_dtype())
pNorm=lambda p: np.sqrt(2) / (2 ** p)
n_moments=lambda g: len(g) // 3
[
    (torch.dot(r ** (p-1), g[0].detach()) * pNorm(p)) ** 2
    for p in range(1, n_moments(g[0]))
]
# Out:
# [tensor(7.8337e-13),
#  tensor(1.9213e-11),
#  tensor(3.8244e-10),
#  tensor(1.8925e-08),
#  tensor(1.0286e-06)]

# %%
[
    (torch.dot(r ** (p-1), wavelet_g) * pNorm(p)) ** 2
    for p in range(1, n_moments(wavelet_g))
]
# Out:
# [tensor(4.4409e-16),
#  tensor(2.8422e-14),
#  tensor(4.5475e-13),
#  tensor(2.9104e-11),
#  tensor(4.6566e-10)]

# %%
inv_model = InverseWaveletBlock1D(model.kernel_size, levels=3, scaling_kernel=h[1], wavelet_kernel=g[1])
inv_model
# Out:
# InverseWaveletBlock1D(
#   (pad): PadSequence()
# )

# %%
XX = inv_model(Ys[-1], Yd)
XX.shape
# Out:
# torch.Size([10, 1, 512])

# %%
((X - XX) ** 2).sum()
# Out:
# tensor(9.6925, grad_fn=<SumBackward0>)
